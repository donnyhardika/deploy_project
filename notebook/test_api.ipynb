# %%
import pandas as pd
import requests

# %%
df = pd.read_csv("../data/test_2025.csv")
df.head()
# Out:
#    claim_number  age_of_driver gender  marital_status  safty_rating  \
# 0          2309             38      M             1.0            87
# 1         22405             43      M             1.0            97
# 2         23398             49      M             1.0            75
# 3         25059             55      M             1.0            70
# 4          2665             22      M             1.0            88
#
#    annual_income  high_education_ind  address_change_ind living_status  \
# 0          56489                   1                   1           Own
# 1         112438                   0                   0           Own
# 2          62518                   1                   0           Own
# 3          96372                   1                   1          Rent
# 4          85049                   0                   1          Rent
#
#    zip_code  ... witness_present_ind liab_prct channel  \
# 0     15012  ...                 0.0        64  Broker
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of        claim_number  age_of_driver gender  marital_status  safty_rating  \
# 0              2309             38      M             1.0            87
# 1             22405             43      M             1.0            97
# 2             23398             49      M             1.0            75
# 3             25059             55      M             1.0            70
# 4              2665             22      M             1.0            88
# ...             ...            ...    ...             ...           ...
# 11995         19032             38      F             1.0            83
# 11996         29526             59      F             1.0            67
# 11997         27075             30      F             1.0            76
# 11998         22683             52      M             0.0            78
# 11999         13707             54      M             1.0            84
#
# ...

# %%
import numpy as np

# %%
feature      = df.copy()
feature      = feature.replace(np.nan,None)
feature_dict = feature.to_dict(orient="records")

# %%
feature_dict
# Out:
# [{'claim_number': 2309,
#   'age_of_driver': 38,
#   'gender': 'M',
#   'marital_status': 1.0,
#   'safty_rating': 87,
#   'annual_income': 56489,
#   'high_education_ind': 1,
#   'address_change_ind': 1,
#   'living_status': 'Own',
#   'zip_code': 15012,
#   'claim_date': '9/18/2016',
#   'claim_day_of_week': 'Sunday',
#   'accident_site': 'Highway',
#   'past_num_of_claims': 0,
#   'witness_present_ind': 0.0,
#   'liab_prct': 64,
#   'channel': 'Broker',
#   'policy_report_filed_ind': 0,
#   'claim_est_payout': 4117.36,
#   'age_of_vehicle': 1,
#   'vehicle_category': 'Compact',
#   'vehicle_price': 15000.0,
#   'vehicle_color': 'gray',
#   'vehicle_weight': 37431.77086},
#  {'claim_number': 22405,
#   'age_of_driver': 43,
#   'gender': 'M',
#   'marital_status': 1.0,
#   'safty_rating': 97,
#   'annual_income': 112438,
#   'high_education_ind': 0,
#   'address_change_ind': 0,
#   'living_status': 'Own',
#   'zip_code': 85077,
#   'claim_date': '5/15/2015',
# ...

# %%
response = requests.post(
    url="http://127.0.0.1:8000/predict", json=feature_dict
)

# %%
response
# Out:
# <Response [422]>

# %%
response.json()
# Out:
# {'detail': [{'type': 'dict_type',
#    'loc': ['body'],
#    'msg': 'Input should be a valid dictionary',
#    'input': [{'claim_number': 2309,
#      'age_of_driver': 38,
#      'gender': 'M',
#      'marital_status': 1.0,
#      'safty_rating': 87,
#      'annual_income': 56489,
#      'high_education_ind': 1,
#      'address_change_ind': 1,
#      'living_status': 'Own',
#      'zip_code': 15012,
#      'claim_date': '9/18/2016',
#      'claim_day_of_week': 'Sunday',
#      'accident_site': 'Highway',
#      'past_num_of_claims': 0,
#      'witness_present_ind': 0.0,
#      'liab_prct': 64,
#      'channel': 'Broker',
#      'policy_report_filed_ind': 0,
#      'claim_est_payout': 4117.36,
#      'age_of_vehicle': 1,
#      'vehicle_category': 'Compact',
#      'vehicle_price': 15000.0,
#      'vehicle_color': 'gray',
#      'vehicle_weight': 37431.77086},
#     {'claim_number': 22405,
#      'age_of_driver': 43,
#      'gender': 'M',
#      'marital_status': 1.0,
# ...
